# %% [markdown]
# # 6 Metodología de Entrenamiento del Modelo
#
# Describe cómo se entrenó el modelo:
# - División de datos (entrenamiento, validación, prueba).
# - Proceso de entrenamiento.
# - Criterios de parada y regularización.

# %% [markdown]
# *[Escribe aquí el contenido de esta sección]*

# %%
# Importaciones
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
