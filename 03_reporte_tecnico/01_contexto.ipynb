# %% [markdown]
# # 1 Contexto
#
# A partir de aquí es adecuado hacer uso de las referencias bibliográficas.
#
# Describe aquí:
# - Contexto y enfoque detallado del proyecto.
# - Motivación y antecedentes.
# - Referencias relevantes.

# %% [markdown]
# *[Escribe aquí el contenido de esta sección]*

# %%
# Importaciones
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
