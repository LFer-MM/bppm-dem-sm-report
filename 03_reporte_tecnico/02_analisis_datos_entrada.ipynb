# %% [markdown]
# # 2 Análisis de Datos de Entrada
#
# Describe y analiza los datos utilizados en el proyecto:
# - Fuente y formato de los datos.
# - Estadísticas descriptivas.
# - Visualizaciones exploratorias.

# %% [markdown]
# *[Escribe aquí el contenido de esta sección]*

# %%
# Importaciones
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
