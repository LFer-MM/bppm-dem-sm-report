# %% [markdown]
# # 4 Modelo de Línea de Base
#
# Describe el modelo de referencia utilizado como punto de comparación:
# - Descripción del modelo base.
# - Métricas de desempeño del modelo base.
# - Justificación de la elección.

# %% [markdown]
# *[Escribe aquí el contenido de esta sección]*

# %%
# Importaciones
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
