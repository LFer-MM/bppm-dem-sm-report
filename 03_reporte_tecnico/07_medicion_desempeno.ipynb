# %% [markdown]
# # 7 Medición del Desempeño
#
# Presenta y analiza las métricas de desempeño del modelo:
# - Métricas utilizadas y su justificación.
# - Resultados obtenidos.
# - Comparación con el modelo de línea de base.

# %% [markdown]
# *[Escribe aquí el contenido de esta sección]*

# %%
# Importaciones
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
